# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.environ['PYTHONPATH'] = '/env/python'

# %%
# %cd '/content/gdrive/My Drive/yolo5_5_xe/yolov5'
# Out:
# /content/gdrive/My Drive/yolo5_5_xe/yolov5

# %%
# !python train.py --data ../data.yaml --weights yolov5s.pt --img 640 --epochs 25 --batch-size 16 --name ket_qua
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.4/618.4 kB 5.5 MB/s eta 0:00:00
# ...
# requirements: Ultralytics requirement ['gitpython'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 29.0 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 4.3s, installed 1 package: ['gitpython']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# ...

# %%
# !python export.py --weights yolo5_5_xe.pt --include onnx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.4/618.4 kB 6.9 MB/s eta 0:00:00
# ...
# export: data=data/coco128.yaml, weights=['yolo5_5_xe.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['onnx']
# YOLOv5 🚀 2023-9-20 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7023610 parameters, 0 gradients
#
# PyTorch: starting from yolo5_5_xe.pt with output shape (1, 25200, 10) (13.8 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 65.3 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 8.0s, installed 1 package: ['onnx>=1.12.0']
# ...

# %%
# !python detect.py --weights yolo5_5_xe.onnx --source XeCuuThuong.jpg
# Out:
# detect: weights=['yolo5_5_xe.onnx'], source=XeCuuThuong.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2023-9-20 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Loading yolo5_5_xe.onnx for ONNX Runtime inference...
# requirements: Ultralytics requirement ['onnxruntime-gpu'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 MB 131.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 211.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 103.9 MB/s eta 0:00:00
# ...
#
# ...
